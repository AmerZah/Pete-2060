# %%
import numpy as np
import pandas as pd
import seaborn as sn 
import scipy.stats as ss
import matplotlib.pyplot as plt

# %%
# import file
df = pd.read_csv(r'C:\Users\aalzah7\Downloads\project_data.csv')

# %%
#check type
df.dtypes
# Out:
# Rst      object
# SGoil    object
# SGgas    object
# Psp      object
# Tsp      object
# dtype: object

# %%
#make type a readable intg. instead of object
df = df.convert_objects(convert_numeric=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
#make sure of type
df.dtypes
# Out:
# Rst      float64
# SGoil    float64
# SGgas    float64
# Psp      float64
# Tsp      float64
# dtype: object

# %%
#get rid of unit row 
df0 = df.drop([0])

# %%
# Transform to log
df1 = np.log10(df)

# %%
df1
# Out:
#            Rst     SGoil     SGgas       Psp       Tsp
# 0          NaN       NaN       NaN       NaN       NaN
# 1     0.206370 -0.096910 -0.221849  1.176091  1.845098
# 2     1.075638 -0.214670 -0.055517  1.838849  1.857332
# 3     1.028313 -0.236572 -0.180456  1.903090  1.792392
# 4     0.886965 -0.055517 -0.091515  2.298853  1.944483
# 5     0.637598 -0.119186 -0.207608  1.934498  2.086360
# 6     1.121210 -0.214670 -0.130768  2.149219  1.977724
# 7     0.839555 -0.080922 -0.080922  2.093422  1.954243
# 8     0.651631 -0.045757 -0.086186  1.913814  1.934498
# 9     0.625883 -0.173925 -0.136677  1.556303  2.130334
# 10    1.018699 -0.154902 -0.180456  2.187521  1.724276
# 11    0.585455 -0.060481 -0.065502  1.653213  1.863323
# 12    0.891932 -0.187087 -0.091515  1.857332  2.117271
# 13    0.439558 -0.065502 -0.221849  1.707570  1.838849
# 14    0.967159 -0.161151 -0.167491  2.201397  2.008600
# 15    0.949825 -0.193820 -0.107905  1.903090  2.004321
# 16    0.824294 -0.086186 -0.096910  2.184691  2.143015
# 17    0.657234 -0.065502 -0.091515  1.838849  1.908485
# 18    0.638988 -0.096910 -0.207608  2.000000  2.033424
# 19    0.611038 -0.045757 -0.187087  2.037426  1.886491
# 20    1.145884 -0.173925 -0.091515  2.152288  1.755875
# 21    0.952098 -0.187087 -0.187087  2.161368  2.100371
# 22    1.196945 -0.214670 -0.050610  2.178977  2.110590
# 23    0.778736 -0.136677 -0.180456  1.851258  1.732394
# 24    0.962795 -0.107905 -0.075721  2.133539  1.863323
# 25    0.597306 -0.060481 -0.070581  1.653213  1.806180
# 26    0.862761 -0.236572 -0.193820  1.819544  2.107210
# 27    0.899593 -0.086186 -0.075721  2.096910  1.832509
# 28    0.913470 -0.091515 -0.060481  2.130334  1.949390
# 29    0.402218 -0.130768 -0.167491  1.380211  2.068186
# ...        ...       ...       ...       ...       ...
# 971   0.728286 -0.065502 -0.187087  2.064458  1.716003
# 972   0.455443 -0.096910 -0.180456  1.643453  2.071882
# 973   1.184608 -0.142668 -0.055517  2.278754  1.770852
# 974   0.830328 -0.130768 -0.214670  2.255273  2.120574
# 975   0.601366 -0.167491 -0.173925  1.568202  2.033424
# 976   0.979167 -0.113509 -0.130768  2.245513  1.838849
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.814695    -0.132479    -0.133348     1.954102     1.959817
# std       0.228489     0.057559     0.055911     0.289862     0.124946
# min       0.130976    -0.236572    -0.236572     1.176091     1.698970
# 25%       0.667094    -0.180456    -0.180456     1.804470     1.857332
# 50%       0.830383    -0.124939    -0.130768     2.033424     1.973128
# 75%       0.978614    -0.080922    -0.086186     2.184691     2.068186
# max       1.345631    -0.045757    -0.045757     2.301030     2.146128

# %%
df0.boxplot(column=['Rst', 'SGoil', 'SGgas','Psp','Tsp'])
plt.show()

# %%
#try to find outliers
z = np.abs(ss.zscore(df01))
print(z)
# Out:
# [[ 2.66370969  0.61826551  1.58366896  2.68541415  0.91860278]
#  [ 1.14260802  1.4286469   1.39272502  0.39781222  0.82063611]
#  [ 0.9353845   1.80934573  0.84297344  0.17607573  1.34064569]
#  ...,
#  [ 0.09494715  0.42714323  1.4552128   1.01433744  0.7467877 ]
#  [ 2.32278102  0.98657888  0.38569915  2.33106063  0.54228065]
#  [ 0.11977096  1.07591634  0.72610777  1.0227827   1.39719306]]

# %%
threshold = 2
print(np.where(z > 2))
# Out:
# (array([  0,   0,  35,  77,  78,  87,  98, 110, 116, 119, 125, 125, 128,
#        128, 130, 131, 136, 176, 178, 197, 204, 204, 209, 220, 220, 221,
#        221, 238, 245, 277, 304, 310, 310, 314, 330, 330, 333, 344, 347,
#        354, 356, 358, 359, 362, 367, 367, 371, 371, 374, 382, 390, 390,
#        401, 404, 415, 415, 438, 438, 444, 444, 458, 464, 464, 470, 491,
#        495, 517, 517, 526, 532, 536, 536, 537, 537, 543, 544, 549, 555,
#        560, 583, 598, 619, 619, 643, 658, 665, 666, 668, 679, 679, 681,
#        697, 699, 699, 702, 714, 722, 725, 745, 766, 766, 768, 789, 799,
#        800, 802, 803, 806, 806, 812, 828, 850, 860, 886, 906, 910, 916,
#        925, 925, 934, 935, 935, 944, 947, 979, 979, 980, 985, 996, 998, 998], dtype=int64), array([0, 3, 4, 0, 3, 3, 3, 3, 0, 0, 0, 3, 0, 3, 3, 3, 3, 3, 3, 3, 0, 3, 3,
#        0, 3, 0, 3, 0, 0, 3, 3, 0, 3, 3, 0, 3, 4, 3, 3, 4, 3, 4, 3, 0, 0, 3,
#        0, 3, 4, 0, 0, 3, 3, 0, 0, 3, 0, 4, 0, 3, 4, 0, 3, 3, 4, 3, 0, 3, 0,
#        0, 0, 3, 0, 4, 4, 0, 3, 0, 3, 3, 3, 0, 3, 3, 3, 4, 0, 3, 0, 3, 4, 4,
#        0, 3, 3, 3, 3, 0, 4, 0, 4, 0, 3, 3, 3, 0, 0, 0, 3, 3, 3, 4, 3, 3, 0,
#        0, 4, 0, 3, 0, 0, 3, 0, 4, 0, 3, 3, 0, 4, 0, 3], dtype=int64))

# %%
sorted(df01)
# Out:
# ['Psp', 'Rst', 'SGgas', 'SGoil', 'Tsp']

# %%
#get rid of outliers for log of the data           
q1, q3= np.percentile(df01,[25,75])
iqr = q3 - q1 
df01_outliers = df01[~((df01 <(q1 - 1.5 * iqr ))| (df01 > (q3 + 1.5 * iqr ))).any(axis=1)]
df01_outliers
# Out:
#            Rst     SGoil     SGgas       Psp       Tsp
# 1     0.206370 -0.096910 -0.221849  1.176091  1.845098
# 989   0.825123 -0.080922 -0.136677  2.296665  2.146128
# 990   0.713567 -0.070581 -0.124939  2.064458  2.045323
# 991   0.519506 -0.119186 -0.214670  1.643453  1.903090
# 992   0.876339 -0.180456 -0.207608  2.060698  2.025306
# 993   0.903078 -0.236572 -0.221849  1.863323  1.949390
# 994   0.696992 -0.060481 -0.229148  2.296665  2.029384
# 995   0.610768 -0.060481 -0.096910  1.913814  2.130334
# 996   0.706214 -0.173925 -0.161151  1.643453  1.939519
# 997   0.845370 -0.091515 -0.200659  2.184691  1.707570
# 998   0.793011 -0.107905 -0.214670  2.247973  2.053078
# 999   0.284230 -0.075721 -0.154902  1.278754  1.892095
# 1000  0.842047 -0.070581 -0.173925  2.250420  1.785330
#
# [1000 rows x 5 columns]

# %%
#get outliers for SGoil for log of the data
q1, q3= np.percentile(df01.SGoil,[25,75])
iqr = q3 - q1 
lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)
upper_bound, lower_bound
# Out:
# (0.068379327627381664, -0.32975729970943912)

# %%
#get outliers for SGgas for log of the data
q1, q3= np.percentile(df01.SGgas,[25,75])
iqr = q3 - q1 
lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)
upper_bound, lower_bound
# Out:
# (0.055218727646488622, -0.32186093972090324)

# %%
#get outliers for Psp for log of the data
q1, q3= np.percentile(df01.Psp,[25,75])
iqr = q3 - q1 
lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)
upper_bound, lower_bound
# Out:
# (2.7550234002670311, 1.2341381484018785)

# %%
#get outliers for Tsp for log of the data
q1, q3= np.percentile(df01.Tsp,[25,75])
iqr = q3 - q1 
lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)
upper_bound, lower_bound
# Out:
# (2.3844659097185015, 1.5410524484589287)

# %%
# start visualizing using log of the data
plt.plot(df01.Rst)
plt.show()

# %%
plt.hist(df01.SGoil)
plt.show()

# %%
plt.loglog(df01.SGgas)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\ticker.py:2210: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   "Data has no positive values, and therefore cannot be "

# %%
plt.pie(df01.Psp)
plt.show()

# %%
plt.subplots(df01.Psp)
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-127-f33d33314707> in <module>()
# ----> 1 plt.subplots(df01.Psp)
#       2 plt.show
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1180     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1181                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1182                        gridspec_kw=gridspec_kw)
#    1183     return fig, axs
#    1184
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1170
#    1171         # Create array to hold all axes.
# -> 1172         axarr = np.empty((nrows, ncols), dtype=object)
#    1173         for row in range(nrows):
#    1174             for col in range(ncols):
#
# TypeError: 'Series' object cannot be interpreted as an integer

# %%
plt.plot(df01.SGoil,df01.SGgas)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#Finding single and multivariable correlations 
corr = df01.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(df01.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(df01.columns)
ax.set_yticklabels(df01.columns)
plt.show()
